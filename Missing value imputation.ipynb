# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 200
plt.rcParams["figure.figsize"] = [20, 4]
df = pd.read_csv("book.csv", parse_dates=['Date'])
df.set_index('Date',inplace=True)
df
# Out:
#               SO2    NO2    CO     O3   PM2.5  Solar Rad  Rainfall  Temp  \
# Date
# 2013-01-01  10.99  64.80  3.01   7.77  178.41     183.69         0  17.0
# 2013-01-02  13.41  71.56  2.73   7.78  204.03     203.27         0  18.4
# 2013-01-03  10.87  67.23  2.45   6.91  278.17     188.48         0  18.9
# 2013-01-04  12.87    NaN  0.96  20.99  191.92     251.45         0  19.9
# 2013-01-05    NaN  55.85   NaN    NaN     NaN     362.78         0  18.7
# ...           ...    ...   ...    ...     ...        ...       ...   ...
# 2018-12-27   2.23  16.67  0.65   3.48  142.14     423.39         0  18.8
# 2018-12-28   1.89  22.17  0.73   4.87  122.22     410.21         0  17.9
# 2018-12-29   2.11  27.58  0.74   7.01  117.56     391.13         0  17.5
# 2018-12-30   2.15  26.76  0.70   9.37  111.88     393.64         0  18.2
# 2018-12-31   2.53  22.14  0.73   7.01  107.16     396.83         0  19.5
#
#             Humidity  Wind Speed    PM10
# Date
# ...

# %%
imp_df = df.interpolate(method="time")
imp_df['PM10'].plot.line()

# %%
imp_df.to_csv(r'imputed data.csv', index = True)
